# %% [markdown]
# # Ćwiczenia - awk

# %% [markdown]
# ## 1. Ponumeruj linie w pliku `equations.dat`

# %%
awk '$0="linia nr "NR" : " $0;' equations.dat
# Out:
# linia nr 1 : 724.96 / 1.37
# linia nr 2 : 782.65 - 848.9
# linia nr 3 : 805.51 + 981.97
# linia nr 4 : 296.5 / 132.77
# linia nr 5 : 477.15 / 217.23
# linia nr 6 : 149.96 - 418.28
# linia nr 7 : 707.83 / 241.16
# linia nr 8 : 750.53 - 329.8
# linia nr 9 : 401.87 / 319.88
# linia nr 10 : 717.33 - 189.74
# linia nr 11 : 443.56 - 666.54
# linia nr 12 : 74.35 / 186.64
# linia nr 13 : 214.57 + 286.47
# linia nr 14 : 97.45 / 415.13
# linia nr 15 : 464.9 + 656.97
# linia nr 16 : 703.0 - 794.15
# linia nr 17 : 363.74 - 922.39
# linia nr 18 : 409.43 - 124.52
# linia nr 19 : 264.97 - 821.85
# linia nr 20 : 975.36 / 836.12
# linia nr 21 : 3.47 - 658.11
# linia nr 22 : 530.86 - 992.17
# linia nr 23 : 590.3 + 281.31
# linia nr 24 : 177.74 - 109.49
# linia nr 25 : 417.4 + 749.52
# linia nr 26 : 972.96 - 63.94
# linia nr 27 : 287.14 - 544.77
# linia nr 28 : 673.16 / 935.52
# linia nr 29 : 666.39 + 759.14
# linia nr 30 : 790.62 / 394.8
# linia nr 31 : 760.85 / 670.27
# linia nr 32 : 705.5 / 703.61
# ...

# %% [markdown]
# ## 2. Wypisz z pliku `equations.dat` tylko działania dodawania z liczbami mniejszymi od 100.

# %%
awk '$1<100 && $3<100 && /\+/' equations.dat
# Out:
# 58.22 + 5.93
# 32.28 + 32.33
# 80.54 + 52.69
# 27.04 + 59.89
# 77.52 + 5.46
# 83.9 + 67.1
# 23.17 + 4.81
# 49.06 + 65.68
# 33.72 + 83.43
# 0.84 + 40.56
# 85.65 + 73.5
# 74.43 + 30.55
# 39.65 + 65.37
# 34.69 + 12.84
# 73.04 + 41.51
# 67.29 + 34.22
# 34.7 + 44.37
# 31.91 + 61.08
# 55.09 + 16.21
# 24.34 + 46.2
# 57.97 + 62.6
# 95.44 + 93.35
# 81.02 + 70.34
# 73.68 + 52.14
# 72.99 + 52.17
# 88.68 + 73.81
# 65.26 + 18.4
# 60.95 + 47.58
# 70.44 + 71.47
# 28.41 + 36.59
# 66.79 + 85.27
# 17.25 + 47.28
# 82.13 + 48.2
# 99.18 + 47.61
# 48.62 + 91.33
# 51.23 + 2.62
# 24.83 + 85.95

# %% [markdown]
# ## 3. Stwórz dodatkową kolumnę na końcu pliku `wyniki.dat` z wyliczoną średnią liczb.

# %%
awk '{print $1,$2,$3,$4,$5,($3+$4+$5)/3}' wyniki.dat
# Out:
# Tomasz 5 17 22  13
# Jan 3 14 22  12
# Maria 6 18 21  13
# Franek 2 15 23  12.6667
# Celina -1 15 24  13
# Piotr 7 19 21  13.3333
# Emilia 3 16 20  12
# Natalia 9 12 24  12
